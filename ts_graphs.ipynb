# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
data = pd.read_csv('~/Desktop/RecreationalCoding/ts_songs_rm_karoake.csv')
data
# Out:
#       Unnamed: 0                                               name  \
# 0              0                                      Lavender Haze
# 1              1                                             Maroon
# 2              2                                          Anti-Hero
# 3              3             Snow On The Beach (feat. Lana Del Rey)
# 4              4                            You're On Your Own, Kid
# ...          ...                                                ...
# 1070        1232                                          Invisible
# 1071        1233                A Perfectly Good Heart - Commentary
# 1072        1234                             A Perfectly Good Heart
# 1073        1235  Teardrops On My Guitar - Pop Version / Commentary
# 1074        1236               Teardrops On My Guitar - Pop Version
#
#                                                  album release_date  \
# 0                              Midnights (3am Edition)   2022-10-22
# ...

# %%
pop_rank = data.nlargest(50, 'popularity')
pop_rank
# Out:
#      Unnamed: 0                                               name  \
# 42           42                                          Anti-Hero
# 40           40                                      Lavender Haze
# 386         401                                     Don’t Blame Me
# 45           45                                      Midnight Rain
# 334         334                                           cardigan
# 594         670                                        Blank Space
# 367         367                                              Lover
# 366         366                                       Cruel Summer
# 43           43             Snow On The Beach (feat. Lana Del Rey)
# 44           44                            You're On Your Own, Kid
# 48           48                                          Bejeweled
# 50           50                                              Karma
# 95           95  All Too Well (10 Minute Version) (Taylor's Ver...
# ...

# %%
plt.bar(courses, values, color ='maroon',
        width = 0.4)
 
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(pop_rank['energy'],pop_rank['popularity'])

# %%
plt.figure(figsize=(12, 8))

plt.subplot(131)
plt.scatter(pop_rank['speechiness'], pop_rank['popularity'],c ="pink",
            linewidths = 2,
            marker ="s",
            edgecolor ="green",
            s = 50)
plt.xlabel('Song Speechiness')
plt.ylabel('Popularity')
plt.subplot(132)
plt.scatter(pop_rank['duration_ms'], pop_rank['popularity'],c ="yellow",
            linewidths = 2,
            marker ="^",
            edgecolor ="red",
            s = 200)
plt.xlabel('Song Duration (in ms)')
plt.show()

# %%
plt.scatter(pop_rank['duration_ms'], pop_rank['popularity'])

# %%
pop_rank.mean()
# Out:
# /var/folders/s6/c2zvps5x2ds8_cjl3p1hyq440000gn/T/ipykernel_6302/2817667731.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pop_rank.mean()
# Unnamed: 0             281.850000
# track_number             8.710000
# acousticness             0.284401
# danceability             0.616270
# energy                   0.551290
# instrumentalness         0.008829
# liveness                 0.133731
# loudness                -8.219180
# speechiness              0.081073
# tempo                  121.946750
# valence                  0.371265
# popularity              73.920000
# duration_ms         227051.080000
# dtype: float64

# %%
plt.bar(pop_rank['liveness'], pop_rank['popularity'], 'r--')
plt.show()

# %%
plt.hist(pop_rank['popularity'], bins=25)
# Out:
# (array([ 1.,  6., 11., 13., 12., 12., 12.,  8.,  4.,  3.,  2.,  8.,  0.,
#          1.,  1.,  3.,  1.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([68.  , 68.92, 69.84, 70.76, 71.68, 72.6 , 73.52, 74.44, 75.36,
#         76.28, 77.2 , 78.12, 79.04, 79.96, 80.88, 81.8 , 82.72, 83.64,
#         84.56, 85.48, 86.4 , 87.32, 88.24, 89.16, 90.08, 91.  ]),
#  <BarContainer object of 25 artists>)

# %%
plt.hist
